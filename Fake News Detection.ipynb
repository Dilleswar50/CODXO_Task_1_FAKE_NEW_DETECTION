# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df_fake = pd.read_csv("Fake.csv")
df_true = pd.read_csv("True.csv")

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_true.shape
# Out:
# (21417, 4)

# %%
df_fake.shape
# Out:
# (23481, 4)

# %%
df_fake["class"] = 0

# %%
df_true["class"] = 1

# %%
df_fake.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
df_fake["class"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 23476    0
# 23477    0
# 23478    0
# 23479    0
# 23480    0
# Name: class, Length: 23481, dtype: int64

# %%
df_true["class"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 21412    1
# 21413    1
# 21414    1
# 21415    1
# 21416    1
# Name: class, Length: 21417, dtype: int64

# %%
df_fake_test = df_fake.tail(25)
df_fake_test
# Out:
#                                                    title  \
# 23456  Eyewash: CIA Elites Misleading Employees Indic...
# 23457  Activist: ‘This is where you can make the most...
# 23458  Episode #120 – SUNDAY WIRE: ‘Crisis of Liberty...
# 23459  FBI Release Oregon Video Footage Depicting Dea...
# 23460  Trial By YouTube: Mainstream Media Use Second-...
# 23461  REPORT: ‘Federal Government Escalated the Viol...
# 23462  BOILER ROOM – Oregon Standoff, Cuddle Parties,...
# 23463  Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23464  Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 23465  ‘There’ll be boots on the ground’: US making n...
# 23466  Boston Brakes? How to Hack a New Car With Your...
# 23467  Oregon Governor Says Feds ‘Must Act’ Against P...
# 23468  Ron Paul on Burns Oregon Standoff and Jury Nul...
# 23469     BOILER ROOM: As the Frogs Slowly Boil – EP #40
# 23470  Arizona Rancher Protesting in Oregon is Target...
# ...

# %%
df_true_test = df_true.tail(25)
df_true_test
# Out:
#                                                    title  \
# 21392  Iran, Saudi Arabia to exchange diplomatic visi...
# 21393  Danish police identify torso as missing submar...
# 21394  Typhoon batters Hong Kong and south China, thr...
# 21395  Poland to allocate additional $55 bllion on de...
# 21396  Pro-Houthi fighters call powerful Yemen ally '...
# 21397  Germany's Schulz says he would demand U.S. wit...
# 21398  Blunt instrument? What a list of banned articl...
# 21399  Saudi police release teenager detained for dan...
# 21400  The People's Princess, Britons work to keep me...
# 21401  Argentina labor unions protest job losses, Mac...
# 21402  Exclusive: Trump's Afghan decision may increas...
# 21403  U.S. puts more pressure on Pakistan to help wi...
# 21404  Exclusive: U.S. to withhold up to $290 million...
# 21405  Trump talks tough on Pakistan's 'terrorist' ha...
# 21406  U.S., North Korea clash at U.N. forum over nuc...
# ...

# %%
for i in range(23480,23455,-1):
    df_fake.drop([i], axis=0, inplace=True)

# %%
df_fake.tail(1)
# Out:
#                                                    title  \
# 23455  BOILER ROOM – Examination, Exclamation, Excita...
#
#                                                     text      subject  \
# 23455  Tune in to the Alternate Current Radio Network...  Middle-east
#
#                    date  class
# 23455  February 3, 2016      0

# %%
for i in range(21416,21391,-1):
    df_true.drop([i], axis=0, inplace=True)

# %%
df_true.tail(1)
# Out:
#                                                    title  \
# 21391  Romanian president opposes plans for judicial ...
#
#                                                     text    subject  \
# 21391  BUCHAREST (Reuters) - Romania s justice minist...  worldnews
#
#                    date  class
# 21391  August 23, 2017       1

# %%
df_fake_test["class"]
# Out:
# 23456    0
# 23457    0
# 23458    0
# 23459    0
# 23460    0
# 23461    0
# 23462    0
# 23463    0
# 23464    0
# 23465    0
# 23466    0
# 23467    0
# 23468    0
# 23469    0
# 23470    0
# 23471    0
# 23472    0
# 23473    0
# 23474    0
# 23475    0
# 23476    0
# 23477    0
# 23478    0
# 23479    0
# 23480    0
# Name: class, dtype: int64

# %%
df_test = pd.concat([df_fake_test, df_true_test], axis=0)

# %%
df_test
# Out:
#                                                    title  \
# 23456  Eyewash: CIA Elites Misleading Employees Indic...
# 23457  Activist: ‘This is where you can make the most...
# 23458  Episode #120 – SUNDAY WIRE: ‘Crisis of Liberty...
# 23459  FBI Release Oregon Video Footage Depicting Dea...
# 23460  Trial By YouTube: Mainstream Media Use Second-...
# 23461  REPORT: ‘Federal Government Escalated the Viol...
# 23462  BOILER ROOM – Oregon Standoff, Cuddle Parties,...
# 23463  Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23464  Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 23465  ‘There’ll be boots on the ground’: US making n...
# 23466  Boston Brakes? How to Hack a New Car With Your...
# 23467  Oregon Governor Says Feds ‘Must Act’ Against P...
# 23468  Ron Paul on Burns Oregon Standoff and Jury Nul...
# 23469     BOILER ROOM: As the Frogs Slowly Boil – EP #40
# 23470  Arizona Rancher Protesting in Oregon is Target...
# ...

# %%
df_test = df_test.sample(frac = 1)

# %%
df_test.reset_index(drop = True, inplace = True)

# %%
df_test
# Out:
#                                                 title  \
# 0   How to Blow $700 Million: Al Jazeera America F...
# 1                       #Hashtag Hell & The Fake Left
# 2   Trump talks tough on Pakistan's 'terrorist' ha...
# 3   ‘There’ll be boots on the ground’: US making n...
# 4   Exclusive: Trump's Afghan decision may increas...
# 5   Saudi police release teenager detained for dan...
# 6   Indonesia to buy $1.14 billion worth of Russia...
# 7   Activist: ‘This is where you can make the most...
# 8   Mata Pires, owner of embattled Brazil builder ...
# 9   Arizona Rancher Protesting in Oregon is Target...
# 10  Seven Iranians freed in the prisoner swap have...
# 11  Boston Brakes? How to Hack a New Car With Your...
# 12  Episode #120 – SUNDAY WIRE: ‘Crisis of Liberty...
# 13  Poland to allocate additional $55 bllion on de...
# 14  Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 15  Argentina labor unions protest job losses, Mac...
# ...

# %%
df = pd.concat([df_fake, df_true], axis = 0)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
df = df.sample(frac=1)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head(10)
# Out:
#                                                title  \
# 0  Afghan Taliban deny former hostage's claims of...
# 1  IT’S A WIN! Karen #Handel Beats Democrat…Crowd...
# 2  OBAMA GUILTS CONGRESSIONAL BLACK CAUCUS Member...
# 3  Dealmakers say a Trump presidency would be bad...
# 4  Gunmen shoot dead police officer and family in...
# 5  19 retired U.S. generals, admirals back Clinto...
# 6  Nobel laureate says Trump policies may lead to...
# 7  BOOM! TRUMP Holds “DISHONEST MEDIA” Accountabl...
# 8  U.S. focus on internal issues will change worl...
# 9   Pantsuit Nation Just Made It EASY To Push For...
#
#                                                 text          subject  \
# 0  PESHAWAR, Pakistan (Reuters) - A Taliban spoke...        worldnews
# 1  Karen Handel won a hard fought Congressional s...         politics
# 2  Obama s narcacism was in full swing on Saturda...  Government News
# 3  (Reuters) - A Donald Trump presidency would be...     politicsNews
# ...

# %%
df.drop(["title", "subject", "date"],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
df.head(10)
# Out:
#                                                 text  class
# 0  PESHAWAR, Pakistan (Reuters) - A Taliban spoke...      1
# 1  Karen Handel won a hard fought Congressional s...      0
# 2  Obama s narcacism was in full swing on Saturda...      0
# 3  (Reuters) - A Donald Trump presidency would be...      1
# 4  ISLAMABAD (Reuters) - Gunmen on a motorcycle s...      1
# 5  (Reuters) - A group of 19 retired U.S. general...      1
# 6  STOCKHOLM (Reuters) - U.S. President-elect Don...      1
# 7  Kellyanne Conway met with NBC s  Meet The Pres...      0
# 8  BERLIN (Reuters) - Less involvement by the Uni...      1
# 9  While a lot of the nation seems to not give a ...      0

# %%
df_test.drop(["title", "subject", "date"],axis = 1, inplace = True)

# %%
df_test.head()
# Out:
#                                                 text  class
# 0  21st Century Wire says Al Jazeera America will...      0
# 1   By Dady Chery and Gilbert MercierAll writers ...      0
# 2  ISLAMABAD (Reuters) - Outlining a new strategy...      1
# 3  21st Century Wire says Various parties in Wash...      0
# 4  ON BOARD A U.S. MILITARY AIRCRAFT (Reuters) - ...      1

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text

# %%
df["text"] = df["text"].apply(wordopt)

# %%
x = df["text"]
y = df["class"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9853728148412415

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5839
#            1       0.98      0.99      0.98      5373
#
#     accuracy                           0.99     11212
#    macro avg       0.99      0.99      0.99     11212
# weighted avg       0.99      0.99      0.99     11212

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test, y_test)
# Out:
# 0.9966999643239386

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5839
#            1       1.00      1.00      1.00      5373
#
#     accuracy                           1.00     11212
#    macro avg       1.00      1.00      1.00     11212
# weighted avg       1.00      1.00      1.00     11212
